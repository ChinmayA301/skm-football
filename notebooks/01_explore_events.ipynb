# %% [markdown]
# # SKM — Explore events parquet
#
# Run `skm-build-events` first, then execute cells below.

# %%
import pandas as pd
from pathlib import Path

path = Path("../data/processed/events.parquet")
df = pd.read_parquet(path)
print(f"{len(df):,} events | {df['match_id'].nunique()} matches | {df['player_id'].nunique()} players")
df.head()

# %%
df["event_type"].value_counts().head(15)

# %%
df.groupby("event_type")["progressive"].mean().sort_values(ascending=False).head(10)
