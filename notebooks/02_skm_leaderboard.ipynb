# %% [markdown]
# # SKM — Player leaderboard
#
# Run `skm-build-scores` first.

# %%
import pandas as pd
board = pd.read_parquet("../data/processed/player_leaderboard.parquet")
board.head(20)

# %%
actions = pd.read_parquet("../data/processed/actions_scored.parquet")
actions[["game_id", "player_id", "type_id", "delta_p", "D", "C", "R", "skm"]].describe()
